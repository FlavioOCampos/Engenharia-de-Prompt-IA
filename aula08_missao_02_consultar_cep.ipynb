# %% [markdown]
# <a href="https://colab.research.google.com/github/FlavioOCampos/Engenharia-de-Prompt-IA/blob/main/aula08_missao_02_consultar_cep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

def consultar_cep(cep):
    # ERRO INTENCIONAL: A URL abaixo está errada (viaceeeep)
    url = f"https://viaceeeep.com.br{cep}/json/"

    try:
        response = requests.get(url)
        # Se o erro não fosse na URL, isso aqui pegaria erros de CEP inexistente
        data = response.json()

        if "erro" in data:
            print("CEP não encontrado.")
        else:
            print(f"Endereço: {data['logradouro']}, {data['bairro']} - {data['localidade']}/{data['uf']}")

    except Exception as e:
        print(f"Ocorreu um erro: {e}")

# Teste
consultar_cep("01001000")
# Out:
# Ocorreu um erro: HTTPSConnectionPool(host='viaceeeep.com.br01001000', port=443): Max retries exceeded with url: /json/ (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7d542e234350>: Failed to resolve 'viaceeeep.com.br01001000' ([Errno -2] Name or service not known)"))

# %%
import requests

def consultar_cep(cep):

    # URL corrigida para o ViaCEP
    url = f"https://viacep.com.br/ws/{cep}/json/"

    try:
        response = requests.get(url)

        # Verifica se a requisição foi bem-sucedida antes de tentar decodificar o JSON
        response.raise_for_status()
        data = response.json()

        if "erro" in data:
            print("CEP não encontrado.")
        else:
            print(f"Endereço: {data['logradouro']}, {data['bairro']} - {data['localidade']}/{data['uf']}")

    except requests.exceptions.RequestException as e:
        # Captura erros específicos de requisição (conexão, timeout, HTTP etc.)
        print(f"Ocorreu um erro de conexão/requisição: {e}")
    except Exception as e:
        # Captura outros erros inesperados
        print(f"Ocorreu um erro inesperado: {e}")


consultar_cep("01001000")
# Out:
# Endereço: Praça da Sé, Sé - São Paulo/SP
