# %% [markdown]
# <a href="https://colab.research.google.com/github/FlavioOCampos/Engenharia-de-Prompt-IA/blob/main/aula07_programa%C3%A7%C3%A3o_assistida_por_IA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# Lista de palavras
palavras = ["python", "computador", "programacao", "faculdade", "desenvolvimento"]

# Escolhe palavra aleatória
palavra = random.choice(palavras)

letras_descobertas = ["_"] * len(palavra)
tentativas = 6
letras_usadas = []

print("🎮 Jogo da Forca")

while tentativas > 0 and "_" in letras_descobertas:
    print("\nPalavra:", " ".join(letras_descobertas))
    print("Tentativas restantes:", tentativas)
    print("Letras usadas:", ", ".join(letras_usadas))

    letra = input("Digite uma letra: ").lower()

    if letra in letras_usadas:
        print("Você já tentou essa letra!")
        continue

    letras_usadas.append(letra)

    if letra in palavra:
        print("Acertou!")
        for i in range(len(palavra)):
            if palavra[i] == letra:
                letras_descobertas[i] = letra
    else:
        print("Errou!")
        tentativas -= 1

# Resultado final
if "_" not in letras_descobertas:
    print("\nParabéns! Você venceu! 🎉")
else:
    print("\nVocê perdeu 😢 A palavra era:", palavra)
# Out:
# 🎮 Jogo da Forca
#
# Palavra: _ _ _ _ _ _
# Tentativas restantes: 6
# Letras usadas:
# Digite uma letra: p
# Acertou!
#
# Palavra: p _ _ _ _ _
# Tentativas restantes: 6
# Letras usadas: p
# Digite uma letra: a
# Errou!
#
# Palavra: p _ _ _ _ _
# Tentativas restantes: 5
# Letras usadas: p, a
# Digite uma letra: s
# Errou!
#
# Palavra: p _ _ _ _ _
# Tentativas restantes: 4
# Letras usadas: p, a, s
# Digite uma letra: d
# Errou!
#
# Palavra: p _ _ _ _ _
# Tentativas restantes: 3
# Letras usadas: p, a, s, d
# Digite uma letra: f
# Errou!
#
# Palavra: p _ _ _ _ _
# Tentativas restantes: 2
# Letras usadas: p, a, s, d, f
# Digite uma letra: f
# Você já tentou essa letra!
#
# Palavra: p _ _ _ _ _
# Tentativas restantes: 2
# Letras usadas: p, a, s, d, f
# Digite uma letra: g
# Errou!
#
# Palavra: p _ _ _ _ _
# Tentativas restantes: 1
# Letras usadas: p, a, s, d, f, g
# Digite uma letra: h
# Acertou!
#
# Palavra: p _ _ h _ _
# Tentativas restantes: 1
# Letras usadas: p, a, s, d, f, g, h
# Digite uma letra: i
# Errou!
#
# Você perdeu 😢 A palavra era: python

# %%
import random

class JogoDaForca:
    def __init__(self, palavras):
        self.palavra_secreta = random.choice(palavras).lower()
        self.letras_descobertas = ["_" for _ in self.palavra_secreta]
        self.tentativas_restantes = 6
        self.letras_usadas = set()
        self.mensagens = {
            "vitoria": "\nParabéns! Você venceu! 🎉 A palavra era: {self.palavra_secreta}",
            "derrota": "\nVocê perdeu 😢 A palavra era: {self.palavra_secreta}",
            "ja_tentou": "Você já tentou essa letra! Tente outra.",
            "entrada_invalida": "Entrada inválida. Por favor, digite apenas uma letra."
        }

    def _mostrar_estado_do_jogo(self):
        print("\nPalavra: ", " ".join(self.letras_descobertas))
        print(f"Tentativas restantes: {self.tentativas_restantes}")
        print("Letras usadas: ", ", ".join(sorted(list(self.letras_usadas))))

    def _obter_palpite(self):
        while True:
            letra = input("Digite uma letra: ").lower()
            if len(letra) != 1 or not letra.isalpha():
                print(self.mensagens["entrada_invalida"])
            elif letra in self.letras_usadas:
                print(self.mensagens["ja_tentou"])
            else:
                self.letras_usadas.add(letra)
                return letra

    def _processar_palpite(self, palpite):
        if palpite in self.palavra_secreta:
            print("Acertou!")
            for i, char in enumerate(self.palavra_secreta):
                if char == palpite:
                    self.letras_descobertas[i] = palpite
        else:
            print("Errou!")
            self.tentativas_restantes -= 1

    def jogar(self):
        print("🎮 Jogo da Forca")
        while self.tentativas_restantes > 0 and "_" in self.letras_descobertas:
            self._mostrar_estado_do_jogo()
            palpite = self._obter_palpite()
            self._processar_palpite(palpite)

        self._mostrar_resultado_final()

    def _mostrar_resultado_final(self):
        if "_" not in self.letras_descobertas:
            print(self.mensagens["vitoria"].format(self=self))
        else:
            print(self.mensagens["derrota"].format(self=self))

# Lista de palavras para o jogo
palavras_disponiveis = ["python", "computador", "programacao", "faculdade", "desenvolvimento"]

# Criar e iniciar o jogo
jogo = JogoDaForca(palavras_disponiveis)
jogo.jogar()
# Out:
# 🎮 Jogo da Forca
#
# Palavra:  _ _ _ _ _ _ _ _ _ _
# Tentativas restantes: 6
# Letras usadas:
# Digite uma letra: p
# Acertou!
#
# Palavra:  _ _ _ p _ _ _ _ _ _
# Tentativas restantes: 6
# Letras usadas:  p
# Digite uma letra: ay
# Entrada inválida. Por favor, digite apenas uma letra.
# Digite uma letra: y
# Errou!
#
# Palavra:  _ _ _ p _ _ _ _ _ _
# Tentativas restantes: 5
# Letras usadas:  p, y
# Digite uma letra: r
# Acertou!
#
# Palavra:  _ _ _ p _ _ _ _ _ r
# Tentativas restantes: 5
# Letras usadas:  p, r, y
# Digite uma letra: c
# Acertou!
#
# Palavra:  c _ _ p _ _ _ _ _ r
# Tentativas restantes: 5
# Letras usadas:  c, p, r, y
# Digite uma letra: o
# Acertou!
#
# Palavra:  c o _ p _ _ _ _ o r
# Tentativas restantes: 5
# Letras usadas:  c, o, p, r, y
# Digite uma letra: m
# Acertou!
#
# Palavra:  c o m p _ _ _ _ o r
# Tentativas restantes: 5
# Letras usadas:  c, m, o, p, r, y
# Digite uma letra: p
# Você já tentou essa letra! Tente outra.
# Digite uma letra: u
# Acertou!
#
# Palavra:  c o m p u _ _ _ o r
# Tentativas restantes: 5
# Letras usadas:  c, m, o, p, r, u, y
# Digite uma letra: t
# Acertou!
#
# Palavra:  c o m p u t _ _ o r
# Tentativas restantes: 5
# Letras usadas:  c, m, o, p, r, t, u, y
# Digite uma letra: a
# Acertou!
#
# Palavra:  c o m p u t a _ o r
# Tentativas restantes: 5
# Letras usadas:  a, c, m, o, p, r, t, u, y
# Digite uma letra: d
# Acertou!
#
# Parabéns! Você venceu! 🎉 A palavra era: computador
